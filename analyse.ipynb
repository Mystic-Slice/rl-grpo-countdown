# %%
from datasets import load_from_disk
from matplotlib import pyplot as plt
import re
import glob
import os
import pandas as pd
import numpy as np

# %%
def format_reward(completion):
    """Reward function that checks if the completion has a specific format."""
    pattern = r"^<reasoning>.*?</reasoning>\s*<answer>.*</answer>$"
    matches = re.match(pattern, completion, re.DOTALL)
    return matches is not None

# %%
def eval_model_answer(equation, nums, target):
    try:
        if equation is None:
            return False

        used_numbers = [int(n) for n in re.findall(r"\d+", equation)]

        # Check if all numbers are used exactly once
        if sorted(used_numbers) != sorted(nums):
            return False

        # Define a regex pattern that only allows numbers, operators, parentheses, and whitespace
        allowed_pattern = r"^[\d+\-*/().\s]+$"
        if not re.match(allowed_pattern, equation):
            return False

        # Evaluate the equation with restricted globals and locals
        result = eval(equation, {"__builtins__": None}, {})
        # Check if the equation is correct and matches the ground truth
        if abs(float(result) - float(target)) < 1e-5:
            return True
        else:
            return False
    except Exception:
        # If evaluation fails, reward is 0
        return False

# %%
EXPERIMENTS = glob.glob("eval_outputs/*")

# %%
results_records = []

# %%
for experiment in EXPERIMENTS:
    checkpoints = glob.glob(os.path.join(experiment, "checkpoint-*"))
    for checkpoint in checkpoints:
        print(f"Evaluating {checkpoint}")
        dataset = load_from_disk(checkpoint)
        format_matches = 0
        correct = 0
        correct_strict = 0
        total = len(dataset)
        for item in dataset:
            if eval_model_answer(item["model_answer"], item["nums"], item["target"]):
                correct += 1
            if format_reward(item["model_response"]):
                format_matches += 1
                if eval_model_answer(item["model_answer"], item["nums"], item["target"]):
                    correct_strict += 1
            
            # print("Model response: ", item['model_response'])
            # print("Format match: ", format_reward(item["model_response"]))
            # print("="*50)
            # break
        accuracy = correct / total
        strict_accuracy = correct_strict / total
        format_accuracy = format_matches / total
        print(f"Accuracy at {checkpoint}: {accuracy:.4f}")
        print(f"Format Accuracy at {checkpoint}: {format_accuracy:.4f}")
        results_records.append({
            "experiment_name": experiment.split("/")[-1],
            "checkpoint_number": int(checkpoint.split("-")[-1]),
            "accuracy": accuracy,
            "strict_accuracy": strict_accuracy,
            "format_accuracy": format_accuracy
        })
# Out:
# Evaluating eval_outputs/rl_equation_base_config/checkpoint-10
# Accuracy at eval_outputs/rl_equation_base_config/checkpoint-10: 0.8000
# Format Accuracy at eval_outputs/rl_equation_base_config/checkpoint-10: 0.8200
# Evaluating eval_outputs/rl_equation_base_config/checkpoint-100
# Accuracy at eval_outputs/rl_equation_base_config/checkpoint-100: 0.0400
# Format Accuracy at eval_outputs/rl_equation_base_config/checkpoint-100: 1.0000
# Evaluating eval_outputs/rl_equation_base_config/checkpoint-110
# Accuracy at eval_outputs/rl_equation_base_config/checkpoint-110: 0.0800
# Format Accuracy at eval_outputs/rl_equation_base_config/checkpoint-110: 1.0000
# Evaluating eval_outputs/rl_equation_base_config/checkpoint-120
# Accuracy at eval_outputs/rl_equation_base_config/checkpoint-120: 0.3100
# Format Accuracy at eval_outputs/rl_equation_base_config/checkpoint-120: 1.0000
# Evaluating eval_outputs/rl_equation_base_config/checkpoint-20
# Accuracy at eval_outputs/rl_equation_base_config/checkpoint-20: 0.7800
# Format Accuracy at eval_outputs/rl_equation_base_config/checkpoint-20: 0.7900
# Evaluating eval_outputs/rl_equation_base_config/checkpoint-30
# Accuracy at eval_outputs/rl_equation_base_config/checkpoint-30: 0.8000
# Format Accuracy at eval_outputs/rl_equation_base_config/checkpoint-30: 0.8200
# Evaluating eval_outputs/rl_equation_base_config/checkpoint-40
# Accuracy at eval_outputs/rl_equation_base_config/checkpoint-40: 0.8200
# Format Accuracy at eval_outputs/rl_equation_base_config/checkpoint-40: 0.8200
# Evaluating eval_outputs/rl_equation_base_config/checkpoint-50
# Accuracy at eval_outputs/rl_equation_base_config/checkpoint-50: 0.6500
# Format Accuracy at eval_outputs/rl_equation_base_config/checkpoint-50: 0.7300
# Evaluating eval_outputs/rl_equation_base_config/checkpoint-60
# Accuracy at eval_outputs/rl_equation_base_config/checkpoint-60: 0.0100
# Format Accuracy at eval_outputs/rl_equation_base_config/checkpoint-60: 1.0000
# Evaluating eval_outputs/rl_equation_base_config/checkpoint-70
# Accuracy at eval_outputs/rl_equation_base_config/checkpoint-70: 0.0000
# Format Accuracy at eval_outputs/rl_equation_base_config/checkpoint-70: 0.9900
# Evaluating eval_outputs/rl_equation_base_config/checkpoint-80
# Accuracy at eval_outputs/rl_equation_base_config/checkpoint-80: 0.0100
# Format Accuracy at eval_outputs/rl_equation_base_config/checkpoint-80: 1.0000
# Evaluating eval_outputs/rl_equation_base_config/checkpoint-90
# Accuracy at eval_outputs/rl_equation_base_config/checkpoint-90: 0.0100
# Format Accuracy at eval_outputs/rl_equation_base_config/checkpoint-90: 1.0000
# Evaluating eval_outputs/rl_equation_base_config_alllinear/checkpoint-10
# Accuracy at eval_outputs/rl_equation_base_config_alllinear/checkpoint-10: 0.7500
# Format Accuracy at eval_outputs/rl_equation_base_config_alllinear/checkpoint-10: 0.7700
# Evaluating eval_outputs/rl_equation_base_config_alllinear/checkpoint-20
# Accuracy at eval_outputs/rl_equation_base_config_alllinear/checkpoint-20: 0.7900
# Format Accuracy at eval_outputs/rl_equation_base_config_alllinear/checkpoint-20: 0.8000
# Evaluating eval_outputs/rl_equation_base_config_alllinear/checkpoint-30
# Accuracy at eval_outputs/rl_equation_base_config_alllinear/checkpoint-30: 0.8500
# Format Accuracy at eval_outputs/rl_equation_base_config_alllinear/checkpoint-30: 0.8500
# Evaluating eval_outputs/rl_equation_base_config_alllinear/checkpoint-40
# Accuracy at eval_outputs/rl_equation_base_config_alllinear/checkpoint-40: 0.6400
# Format Accuracy at eval_outputs/rl_equation_base_config_alllinear/checkpoint-40: 0.6400
# Evaluating eval_outputs/rl_equation_base_config_alllinear/checkpoint-50
# Accuracy at eval_outputs/rl_equation_base_config_alllinear/checkpoint-50: 0.0700
# Format Accuracy at eval_outputs/rl_equation_base_config_alllinear/checkpoint-50: 0.1900
# Evaluating eval_outputs/rl_equation_base_config_alllinear_kl_largebeta/checkpoint-10
# Accuracy at eval_outputs/rl_equation_base_config_alllinear_kl_largebeta/checkpoint-10: 0.8000
# Format Accuracy at eval_outputs/rl_equation_base_config_alllinear_kl_largebeta/checkpoint-10: 0.8100
# Evaluating eval_outputs/rl_equation_base_config_alllinear_kl_largebeta/checkpoint-20
# Accuracy at eval_outputs/rl_equation_base_config_alllinear_kl_largebeta/checkpoint-20: 0.7900
# Format Accuracy at eval_outputs/rl_equation_base_config_alllinear_kl_largebeta/checkpoint-20: 0.8100
# Evaluating eval_outputs/rl_equation_base_config_alllinear_kl_largebeta/checkpoint-30
# Accuracy at eval_outputs/rl_equation_base_config_alllinear_kl_largebeta/checkpoint-30: 0.7900
# Format Accuracy at eval_outputs/rl_equation_base_config_alllinear_kl_largebeta/checkpoint-30: 0.7900
# Evaluating eval_outputs/rl_equation_base_config_alllinear_kl_largebeta/checkpoint-40
# Accuracy at eval_outputs/rl_equation_base_config_alllinear_kl_largebeta/checkpoint-40: 0.7400
# Format Accuracy at eval_outputs/rl_equation_base_config_alllinear_kl_largebeta/checkpoint-40: 0.7400
# Evaluating eval_outputs/rl_equation_base_config_kl_0.0001_beta/checkpoint-10
# Accuracy at eval_outputs/rl_equation_base_config_kl_0.0001_beta/checkpoint-10: 0.7400
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_0.0001_beta/checkpoint-10: 0.7600
# Evaluating eval_outputs/rl_equation_base_config_kl_0.0001_beta/checkpoint-20
# Accuracy at eval_outputs/rl_equation_base_config_kl_0.0001_beta/checkpoint-20: 0.7800
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_0.0001_beta/checkpoint-20: 0.7800
# Evaluating eval_outputs/rl_equation_base_config_kl_0.0001_beta/checkpoint-30
# Accuracy at eval_outputs/rl_equation_base_config_kl_0.0001_beta/checkpoint-30: 0.8100
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_0.0001_beta/checkpoint-30: 0.8100
# Evaluating eval_outputs/rl_equation_base_config_kl_0.0001_beta/checkpoint-40
# Accuracy at eval_outputs/rl_equation_base_config_kl_0.0001_beta/checkpoint-40: 0.6800
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_0.0001_beta/checkpoint-40: 0.7100
# Evaluating eval_outputs/rl_equation_base_config_kl_0.01_beta/checkpoint-10
# Accuracy at eval_outputs/rl_equation_base_config_kl_0.01_beta/checkpoint-10: 0.8200
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_0.01_beta/checkpoint-10: 0.8300
# Evaluating eval_outputs/rl_equation_base_config_kl_0.01_beta/checkpoint-20
# Accuracy at eval_outputs/rl_equation_base_config_kl_0.01_beta/checkpoint-20: 0.8500
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_0.01_beta/checkpoint-20: 0.8500
# Evaluating eval_outputs/rl_equation_base_config_kl_0.01_beta/checkpoint-30
# Accuracy at eval_outputs/rl_equation_base_config_kl_0.01_beta/checkpoint-30: 0.7700
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_0.01_beta/checkpoint-30: 0.7700
# Evaluating eval_outputs/rl_equation_base_config_kl_0.01_beta/checkpoint-40
# Accuracy at eval_outputs/rl_equation_base_config_kl_0.01_beta/checkpoint-40: 0.7800
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_0.01_beta/checkpoint-40: 0.7800
# Evaluating eval_outputs/rl_equation_base_config_kl_0.1_beta/checkpoint-10
# Accuracy at eval_outputs/rl_equation_base_config_kl_0.1_beta/checkpoint-10: 0.7900
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_0.1_beta/checkpoint-10: 0.8000
# Evaluating eval_outputs/rl_equation_base_config_kl_0.1_beta/checkpoint-20
# Accuracy at eval_outputs/rl_equation_base_config_kl_0.1_beta/checkpoint-20: 0.7600
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_0.1_beta/checkpoint-20: 0.7600
# Evaluating eval_outputs/rl_equation_base_config_kl_0.1_beta/checkpoint-30
# Accuracy at eval_outputs/rl_equation_base_config_kl_0.1_beta/checkpoint-30: 0.8000
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_0.1_beta/checkpoint-30: 0.8100
# Evaluating eval_outputs/rl_equation_base_config_kl_0.1_beta/checkpoint-40
# Accuracy at eval_outputs/rl_equation_base_config_kl_0.1_beta/checkpoint-40: 0.7800
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_0.1_beta/checkpoint-40: 0.7800
# Evaluating eval_outputs/rl_equation_base_config_kl_high_lr/checkpoint-10
# Accuracy at eval_outputs/rl_equation_base_config_kl_high_lr/checkpoint-10: 0.8000
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_high_lr/checkpoint-10: 0.8200
# Evaluating eval_outputs/rl_equation_base_config_kl_high_lr/checkpoint-20
# Accuracy at eval_outputs/rl_equation_base_config_kl_high_lr/checkpoint-20: 0.5000
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_high_lr/checkpoint-20: 0.9000
# Evaluating eval_outputs/rl_equation_base_config_kl_high_lr/checkpoint-30
# Accuracy at eval_outputs/rl_equation_base_config_kl_high_lr/checkpoint-30: 0.5300
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_high_lr/checkpoint-30: 0.9200
# Evaluating eval_outputs/rl_equation_base_config_kl_high_lr/checkpoint-40
# Accuracy at eval_outputs/rl_equation_base_config_kl_high_lr/checkpoint-40: 0.6100
# Format Accuracy at eval_outputs/rl_equation_base_config_kl_high_lr/checkpoint-40: 0.7400
# Evaluating eval_outputs/rl_equation_first/checkpoint-20
# Accuracy at eval_outputs/rl_equation_first/checkpoint-20: 0.7500
# Format Accuracy at eval_outputs/rl_equation_first/checkpoint-20: 0.0000
# Evaluating eval_outputs/rl_equation_first/checkpoint-40
# Accuracy at eval_outputs/rl_equation_first/checkpoint-40: 0.7400
# Format Accuracy at eval_outputs/rl_equation_first/checkpoint-40: 0.0000
# Evaluating eval_outputs/rl_equation_first/checkpoint-60
# Accuracy at eval_outputs/rl_equation_first/checkpoint-60: 0.2900
# Format Accuracy at eval_outputs/rl_equation_first/checkpoint-60: 0.0000
# Evaluating eval_outputs/rl_equation_first/checkpoint-80
# Accuracy at eval_outputs/rl_equation_first/checkpoint-80: 0.0100
# Format Accuracy at eval_outputs/rl_equation_first/checkpoint-80: 0.0000
# Evaluating eval_outputs/rl_equation_think/checkpoint-20
# Accuracy at eval_outputs/rl_equation_think/checkpoint-20: 0.7900
# Format Accuracy at eval_outputs/rl_equation_think/checkpoint-20: 0.8000
# Evaluating eval_outputs/rl_equation_think/checkpoint-40
# Accuracy at eval_outputs/rl_equation_think/checkpoint-40: 0.1000
# Format Accuracy at eval_outputs/rl_equation_think/checkpoint-40: 0.8200
# Evaluating eval_outputs/rl_equation_think/checkpoint-60
# Accuracy at eval_outputs/rl_equation_think/checkpoint-60: 0.0000
# Format Accuracy at eval_outputs/rl_equation_think/checkpoint-60: 1.0000
# Evaluating eval_outputs/rl_equation_think_base_config_backup/checkpoint-10
# Accuracy at eval_outputs/rl_equation_think_base_config_backup/checkpoint-10: 0.7900
# Format Accuracy at eval_outputs/rl_equation_think_base_config_backup/checkpoint-10: 0.7900
# Evaluating eval_outputs/rl_equation_think_base_config_backup/checkpoint-20
# Accuracy at eval_outputs/rl_equation_think_base_config_backup/checkpoint-20: 0.7800
# Format Accuracy at eval_outputs/rl_equation_think_base_config_backup/checkpoint-20: 0.8200
# Evaluating eval_outputs/rl_equation_think_base_config_backup/checkpoint-30
# Accuracy at eval_outputs/rl_equation_think_base_config_backup/checkpoint-30: 0.8000
# Format Accuracy at eval_outputs/rl_equation_think_base_config_backup/checkpoint-30: 0.8100
# Evaluating eval_outputs/rl_equation_think_base_config_backup/checkpoint-40
# Accuracy at eval_outputs/rl_equation_think_base_config_backup/checkpoint-40: 0.8200
# Format Accuracy at eval_outputs/rl_equation_think_base_config_backup/checkpoint-40: 0.8300
# Evaluating eval_outputs/rl_equation_think_base_config_backup/checkpoint-50
# Accuracy at eval_outputs/rl_equation_think_base_config_backup/checkpoint-50: 0.6400
# Format Accuracy at eval_outputs/rl_equation_think_base_config_backup/checkpoint-50: 0.7100

# %%
results_df = pd.DataFrame.from_records(results_records)

# %%
results_df.sort_values(by=["experiment_name", "checkpoint_number"], inplace=True)

# %%
results_df
# Out:
#                                    experiment_name  checkpoint_number  \
# 0                          rl_equation_base_config                 10
# 4                          rl_equation_base_config                 20
# 5                          rl_equation_base_config                 30
# 6                          rl_equation_base_config                 40
# 7                          rl_equation_base_config                 50
# 8                          rl_equation_base_config                 60
# 9                          rl_equation_base_config                 70
# 10                         rl_equation_base_config                 80
# 11                         rl_equation_base_config                 90
# 1                          rl_equation_base_config                100
# 2                          rl_equation_base_config                110
# 3                          rl_equation_base_config                120
# 12               rl_equation_base_config_alllinear                 10
# 13               rl_equation_base_config_alllinear                 20
# 14               rl_equation_base_config_alllinear                 30
# 15               rl_equation_base_config_alllinear                 40
# 16               rl_equation_base_config_alllinear                 50
# 17  rl_equation_base_config_alllinear_kl_largebeta                 10
# 18  rl_equation_base_config_alllinear_kl_largebeta                 20
# 19  rl_equation_base_config_alllinear_kl_largebeta                 30
# 20  rl_equation_base_config_alllinear_kl_largebeta                 40
# 21          rl_equation_base_config_kl_0.0001_beta                 10
# 22          rl_equation_base_config_kl_0.0001_beta                 20
# 23          rl_equation_base_config_kl_0.0001_beta                 30
# 24          rl_equation_base_config_kl_0.0001_beta                 40
# 25            rl_equation_base_config_kl_0.01_beta                 10
# 26            rl_equation_base_config_kl_0.01_beta                 20
# 27            rl_equation_base_config_kl_0.01_beta                 30
# 28            rl_equation_base_config_kl_0.01_beta                 40
# 29             rl_equation_base_config_kl_0.1_beta                 10
# 30             rl_equation_base_config_kl_0.1_beta                 20
# 31             rl_equation_base_config_kl_0.1_beta                 30
# 32             rl_equation_base_config_kl_0.1_beta                 40
# 33              rl_equation_base_config_kl_high_lr                 10
# 34              rl_equation_base_config_kl_high_lr                 20
# 35              rl_equation_base_config_kl_high_lr                 30
# 36              rl_equation_base_config_kl_high_lr                 40
# 37                               rl_equation_first                 20
# 38                               rl_equation_first                 40
# 39                               rl_equation_first                 60
# 40                               rl_equation_first                 80
# 41                               rl_equation_think                 20
# 42                               rl_equation_think                 40
# 43                               rl_equation_think                 60
# 44            rl_equation_think_base_config_backup                 10
# 45            rl_equation_think_base_config_backup                 20
# 46            rl_equation_think_base_config_backup                 30
# 47            rl_equation_think_base_config_backup                 40
# 48            rl_equation_think_base_config_backup                 50
#
#     accuracy  strict_accuracy  format_accuracy
# 0       0.80             0.80             0.82
# 4       0.78             0.78             0.79
# 5       0.80             0.80             0.82
# 6       0.82             0.82             0.82
# 7       0.65             0.65             0.73
# 8       0.01             0.01             1.00
# 9       0.00             0.00             0.99
# 10      0.01             0.01             1.00
# 11      0.01             0.01             1.00
# 1       0.04             0.04             1.00
# 2       0.08             0.08             1.00
# 3       0.31             0.31             1.00
# 12      0.75             0.75             0.77
# 13      0.79             0.79             0.80
# 14      0.85             0.85             0.85
# 15      0.64             0.64             0.64
# 16      0.07             0.07             0.19
# 17      0.80             0.80             0.81
# 18      0.79             0.79             0.81
# 19      0.79             0.79             0.79
# 20      0.74             0.74             0.74
# 21      0.74             0.74             0.76
# 22      0.78             0.78             0.78
# 23      0.81             0.81             0.81
# 24      0.68             0.68             0.71
# 25      0.82             0.82             0.83
# 26      0.85             0.85             0.85
# 27      0.77             0.77             0.77
# 28      0.78             0.78             0.78
# 29      0.79             0.79             0.80
# 30      0.76             0.76             0.76
# 31      0.80             0.80             0.81
# 32      0.78             0.78             0.78
# 33      0.80             0.80             0.82
# 34      0.50             0.50             0.90
# 35      0.53             0.53             0.92
# 36      0.61             0.61             0.74
# 37      0.75             0.00             0.00
# 38      0.74             0.00             0.00
# 39      0.29             0.00             0.00
# 40      0.01             0.00             0.00
# 41      0.79             0.79             0.80
# 42      0.10             0.10             0.82
# 43      0.00             0.00             1.00
# 44      0.79             0.79             0.79
# 45      0.78             0.78             0.82
# 46      0.80             0.80             0.81
# 47      0.82             0.82             0.83
# 48      0.64             0.64             0.71

# %%
EXPERIMENTS_ORDER = [
    'rl_equation_base_config', 
    'rl_equation_base_config_kl_0.0001_beta', 
    'rl_equation_base_config_kl_0.01_beta', 
    'rl_equation_base_config_kl_0.1_beta', 
    'rl_equation_base_config_kl_high_lr', 
    'rl_equation_base_config_alllinear', 
    'rl_equation_base_config_alllinear_kl_largebeta', 
    'rl_equation_first', 
    'rl_equation_think', 
]

# %%
idx = results_df.groupby("experiment_name")["accuracy"].idxmax()
idx = idx.reindex(EXPERIMENTS_ORDER).dropna().astype(int)
best_results_df = results_df.loc[idx]
best_results_df
# Out:
#                                    experiment_name  checkpoint_number  \
# 6                          rl_equation_base_config                 40
# 23          rl_equation_base_config_kl_0.0001_beta                 30
# 26            rl_equation_base_config_kl_0.01_beta                 20
# 31             rl_equation_base_config_kl_0.1_beta                 30
# 33              rl_equation_base_config_kl_high_lr                 10
# 14               rl_equation_base_config_alllinear                 30
# 17  rl_equation_base_config_alllinear_kl_largebeta                 10
# 37                               rl_equation_first                 20
# 41                               rl_equation_think                 20
#
#     accuracy  strict_accuracy  format_accuracy
# 6       0.82             0.82             0.82
# 23      0.81             0.81             0.81
# 26      0.85             0.85             0.85
# 31      0.80             0.80             0.81
# 33      0.80             0.80             0.82
# 14      0.85             0.85             0.85
# 17      0.80             0.80             0.81
# 37      0.75             0.00             0.00
# 41      0.79             0.79             0.80

# %%
idx = results_df.groupby("experiment_name")["strict_accuracy"].idxmax()
idx = idx.reindex(EXPERIMENTS_ORDER).dropna().astype(int)
best_results_df = results_df.loc[idx]
best_results_df
# Out:
#                                    experiment_name  checkpoint_number  \
# 6                          rl_equation_base_config                 40
# 23          rl_equation_base_config_kl_0.0001_beta                 30
# 26            rl_equation_base_config_kl_0.01_beta                 20
# 31             rl_equation_base_config_kl_0.1_beta                 30
# 33              rl_equation_base_config_kl_high_lr                 10
# 14               rl_equation_base_config_alllinear                 30
# 17  rl_equation_base_config_alllinear_kl_largebeta                 10
# 37                               rl_equation_first                 20
# 41                               rl_equation_think                 20
#
#     accuracy  strict_accuracy  format_accuracy
# 6       0.82             0.82             0.82
# 23      0.81             0.81             0.81
# 26      0.85             0.85             0.85
# 31      0.80             0.80             0.81
# 33      0.80             0.80             0.82
# 14      0.85             0.85             0.85
# 17      0.80             0.80             0.81
# 37      0.75             0.00             0.00
# 41      0.79             0.79             0.80
